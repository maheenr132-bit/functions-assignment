# %%
#Q:no:1
import datetime as dt
def greet_with_time(name):
    current_time =  dt.datetime.now()
    print(f"Hello, {name}! The current time is {current_time}.")
greet_with_time("maheen")
# Out:
# Hello, maheen! The current time is 2025-12-02 09:57:25.635669.

# %%
#Q:no:2
def calculate_average(num1,num2,num3):
    average = ((num1+num2+num3)/3)
    print (average)
calculate_average(4,5,6)
# Out:
# 5.0

# %%
#Q:no:3
def calculate_discount(price,discount_percentage=10):
    discount_amount= ((price*discount_percentage)/100)
    print(discount_amount)
calculate_discount(2000)
# Out:
# 1800.0

# %%
def print_info(name,age,city):
    print(f"Name={name}\n Age={age}\n City={city}")
print_info("maheen","19","lahore")
# Out:
# Name=maheen
#  Age=19
#  City=lahore

# %%
def find_max(*args):
    if not args:
        return none
    return max(args)
result = find_max(10,20,55,66,88)
print(f"the maximum value is:{result}")
# Out:
# the maximum value is:88
